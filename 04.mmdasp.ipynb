# %% [markdown]
# # Adesso adaptado no Colab

# %% [markdown]
# ## Vídeos antigos
# * [Adesso2-mmd-1-9 (76min)](https://www.loom.com/share/a8373d5d902a4317820c8c7ef31d5524), após 39min

# %%
import matplotlib.pyplot as plt
from PIL import Image
import cv2, requests, sys
import numpy as np

# %%
# download _morph.py from drive
# !pip install -U --no-cache-dir gdown --pre
# !gdown --id 1FlMtAkb0npwmD54aCysLsxB84PehcKMe
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
# ...
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1FlMtAkb0npwmD54aCysLsxB84PehcKMe
# From (redirected): https://drive.google.com/uc?id=1FlMtAkb0npwmD54aCysLsxB84PehcKMe&confirm=t&uuid=55cb9449-e0bf-412e-8644-586680286686
# To: /content/_morph.py
# 100% 39.2k/39.2k [00:00<00:00, 34.6MB/s]

# %%
from _morph import *

# %% [markdown]
# # mmdasp

# %%
img = mm.read('https://drive.google.com/file/d/1kG-LyIZoJBlljKqb2oYx4LKycCR99ZQE/view?usp=sharing')
a = cv2.cvtColor(img ,cv2.COLOR_BGR2GRAY) # converte para grayscale
plt.figure(figsize=(10, 10))
mm.show(a)

# %%
#b = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(5,5))
#open = cv2.morphologyEx(f, cv2.MORPH_OPEN, b)
c = mm.regmax(a,mm.sebox())
plt.figure(figsize=(10, 10))
mm.show(img,c)

# %%
d = mm.open(a, mm.sedisk(40));
plt.figure(figsize=(10, 10))
mm.show(d);

# %%
f = mm.regmax(d,mm.sebox());
plt.figure(figsize=(10, 10))
mm.show(img,f)
np.amax(mm.label(f))
# Out:
# 7

# %%
plt.figure(figsize=(10, 10))
mm.show(img,mm.gradm(f));
