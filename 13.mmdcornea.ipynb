# %% [markdown]
# # Adesso adaptado neste Colab

# %% [markdown]
# ## Vídeos antigos
# * [Adesso3-mmd-9-17 (76min)](https://www.loom.com/share/2da4f118c66547cdb4000f5206bfb7d7), após 50m

# %%
import matplotlib.pyplot as plt
from PIL import Image
import cv2, requests, sys
import numpy as np

# %%
# download _morph.py from drive
# !pip install -U --no-cache-dir gdown --pre
# !gdown --id 1FlMtAkb0npwmD54aCysLsxB84PehcKMe
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
# ...
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1FlMtAkb0npwmD54aCysLsxB84PehcKMe
# From (redirected): https://drive.google.com/uc?id=1FlMtAkb0npwmD54aCysLsxB84PehcKMe&confirm=t&uuid=4791fd27-e1d6-4312-980e-e8deebbacf9c
# To: /content/_morph.py
# 100% 39.2k/39.2k [00:00<00:00, 7.66MB/s]

# %%
from _morph import *

# %% [markdown]
# # mmdcornea

# %%
img = mm.read('https://drive.google.com/file/d/18uCZQ4ZGP8rhmpMf6YAUIQUPavkxSfzE/view?usp=sharing')
a = cv2.cvtColor(img ,cv2.COLOR_BGR2GRAY) # converte para grayscale
plt.figure(figsize=(7, 7))
mm.show(a)

# %%
b = mm.asf(a,'oc',mm.secross(0),2)
plt.figure(figsize=(7, 7))
mm.show(b)

# %%
d = mm.regmax(b,mm.secross(7))
e = d#mm.dil(d,mm.sebox(0))
plt.figure(figsize=(7, 7))
mm.show(img,e)

# %%
img0 = img.copy()
f = mm.watershed([],e,'line')
plt.figure(figsize=(7, 7))
mm.show(img0,f,e)
