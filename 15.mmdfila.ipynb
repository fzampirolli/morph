# %% [markdown]
# # Adesso adaptado neste Colab

# %% [markdown]
# ## Vídeos antigos
# * [Adesso3-mmd-9-17 (76min)](https://www.loom.com/share/2da4f118c66547cdb4000f5206bfb7d7), após 1h2m

# %%
import matplotlib.pyplot as plt
from PIL import Image
import cv2, requests, sys
import numpy as np

# %%
# download _morph.py from drive
# !pip install -U --no-cache-dir gdown --pre
# !gdown --id 1FlMtAkb0npwmD54aCysLsxB84PehcKMe

# %%
from _morph import *

# %% [markdown]
# # mmdfila

# %%
img = mm.read('https://drive.google.com/file/d/1VGpQcWyrwxEEcTf5DqbFVmZ2e1yrindF/view?usp=sharing')
a = cv2.cvtColor(img ,cv2.COLOR_BGR2GRAY) # converte para grayscale
#ret2,f = cv2.threshold(f,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
plt.figure(figsize=(7, 7))
mm.show(a)

# %%
b = mm.closerecth(a,mm.sebox(5))
plt.figure(figsize=(7, 7))
mm.show(b)

# %%
c = mm.open(b)
plt.figure(figsize=(7, 7))
mm.show(c)

# %%
d = mm.areaopen(c,100)
plt.figure(figsize=(7, 7))
mm.show(d)

# %%
e = np.array(d>500000)
plt.figure(figsize=(7, 7))
mm.show(e)

# %%
f = mm.thin(e)
plt.figure(figsize=(7, 7))
mm.show(f)

# %%
plt.figure(figsize=(7, 7))
mm.show(img,mm.gradm(f.astype('uint8')))
