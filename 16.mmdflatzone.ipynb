# %% [markdown]
# # Adesso adaptado neste Colab

# %% [markdown]
# ## Vídeos antigos
# * [Adesso3-mmd-9-17 (76min)](https://www.loom.com/share/2da4f118c66547cdb4000f5206bfb7d7), após 1h6m

# %%
import matplotlib.pyplot as plt
from PIL import Image
import cv2, requests, sys
import numpy as np

# %%
# download _morph.py from drive
# !pip install -U --no-cache-dir gdown --pre
# !gdown --id 1FlMtAkb0npwmD54aCysLsxB84PehcKMe

# %%
from _morph import *

# %% [markdown]
# # mmdflatzone

# %%
img = mm.read('https://drive.google.com/file/d/1BYukdDY4LA7hVUEo4LxcKOZuRHAi5q4W/view?usp=sharing')
a = cv2.cvtColor(img ,cv2.COLOR_BGR2GRAY) # converte para grayscale
plt.figure(figsize=(7, 7))
mm.show(a)

# %%
b = cv2.getStructuringElement(cv2.MORPH_CROSS,(3,3))
c=mm.asf(a,'CO',mm.sebox(),2)
plt.figure(figsize=(7, 7))
mm.show(c)

# %%
d=mm.asf(a,'CO',mm.sebox(),4)
plt.figure(figsize=(7, 7))
mm.show(d)

# %%
e=mm.asf(a,'CO',mm.sebox(),16)
plt.figure(figsize=(7, 7))
mm.show(e)
