# %% [markdown]
# # Adesso adaptado neste Colab

# %% [markdown]
# ## Vídeos antigos
# * [Adesso4-mmd-18-27 (54min)](https://www.loom.com/share/5186fcc96309454e8e0ff90360825589)

# %%
import matplotlib.pyplot as plt
from PIL import Image
import cv2, requests, sys
import numpy as np

# %%
# download _morph.py from drive
# !pip install -U --no-cache-dir gdown --pre
# !gdown --id 1FlMtAkb0npwmD54aCysLsxB84PehcKMe

# %%
from _morph import *

# %% [markdown]
# # mmdgear

# %%
img = mm.read('https://drive.google.com/file/d/1jb25bp6S7zCeNXDXSEJifBcU98kOk0tk/view?usp=sharing')
a = cv2.cvtColor(img ,cv2.COLOR_BGR2GRAY) # converte para grayscale
ret2,a = cv2.threshold(a,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
plt.figure(figsize=(7, 7))
mm.show(a)

# %%
b = np.array(mm.open(a,mm.sedisk(21))>0, dtype='uint8')*255
plt.figure(figsize=(7, 7))
mm.show(b)

# %%
c = mm.subm(a,b)
#c = mm.open(c,mm.secross())
plt.figure(figsize=(7, 7))
mm.show(c)

# %%
d = mm.label(np.array(c,dtype='uint8'))
plt.figure(figsize=(7, 7))
mm.show(d)
np.amax(d)
# Out:
# 24

# %%
plt.figure(figsize=(7, 7))
_=mm.blob(c,'textLabel')

# %%
mm.lblshow(c,5)
