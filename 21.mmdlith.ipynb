# %% [markdown]
# # Adesso adaptado neste Colab

# %% [markdown]
# ## Vídeos antigos
# * [Adesso4-mmd-18-27 (54min)](https://www.loom.com/share/5186fcc96309454e8e0ff90360825589), após 22m

# %%
import matplotlib.pyplot as plt
from PIL import Image
import cv2, requests, sys
import numpy as np

# %%
# download _morph.py from drive
# !pip install -U --no-cache-dir gdown --pre
# !gdown --id 1FlMtAkb0npwmD54aCysLsxB84PehcKMe

# %%
from _morph import *

# %% [markdown]
# # mmdlith

# %%
img = mm.read('https://drive.google.com/file/d/139lWgm5cnG0bbTG6hf2qkm9bMx0aQzQp/view?usp=sharing')
a = cv2.cvtColor(img ,cv2.COLOR_BGR2GRAY) # converte para grayscale
plt.figure(figsize=(7, 7))
mm.show(a)

# %%
B = np.ones((27,3),dtype= 'uint8')
b = mm.close(a,B)
plt.figure(figsize=(7, 7))
mm.show(b)

# %%
c = mm.subm(b,a)
plt.figure(figsize=(7, 7))
mm.show(c)

# %%
d = np.array(c>50,dtype='uint8')
e = mm.areaopen(d,20)
plt.figure(figsize=(7, 7))
mm.show(img,e)
