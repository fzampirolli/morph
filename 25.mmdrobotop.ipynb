# %% [markdown]
# # Adesso adaptado neste Colab

# %% [markdown]
# ## Vídeos antigos
# * [Adesso4-mmd-18-27 (54min)](https://www.loom.com/share/5186fcc96309454e8e0ff90360825589), após 47m

# %%
import matplotlib.pyplot as plt
from PIL import Image
import cv2, requests, sys
import numpy as np

# %%
# download _morph.py from drive
# !pip install -U --no-cache-dir gdown --pre
# !gdown --id 1FlMtAkb0npwmD54aCysLsxB84PehcKMe

# %%
from _morph import *

# %% [markdown]
# # mmdrobotop

# %%
img = mm.read('https://drive.google.com/file/d/1CZrxOn8-6nufzPcoVRI3n32lTwo2lRcJ/view?usp=sharing')
a = cv2.cvtColor(img ,cv2.COLOR_BGR2GRAY) # converte para grayscale
mm.show(a)

# %%
b = mm.openth(a,mm.sebox(2))
mm.show(b)

# %%
c = mm.open(b,mm.sebox())
mm.show(c)

# %%
d = mm.threshold(c,100)
mm.show(img,d)
