# %% [markdown]
# # Adesso adaptado neste Colab

# %% [markdown]
# ## Vídeos antigos
# * [Adesso4-mmd-18-27 (54min)](https://www.loom.com/share/5186fcc96309454e8e0ff90360825589), após 48m

# %%
import matplotlib.pyplot as plt
from PIL import Image
import cv2, requests, sys
import numpy as np

# %%
# download _morph.py from drive
# !pip install -U --no-cache-dir gdown --pre
# !gdown --id 1FlMtAkb0npwmD54aCysLsxB84PehcKMe

# %%
from _morph import *

# %% [markdown]
# # mmdruler

# %%
img = mm.read('https://drive.google.com/file/d/1xttc62Wk1fQgAz4JeDwuZ4osPV64NpIE/view?usp=sharing')
a = cv2.cvtColor(img ,cv2.COLOR_BGR2GRAY) # converte para grayscale
mm.show(a)

# %%
b = mm.threshold(mm.closeth(a,mm.sebox(4)),30)
mm.show(b)

# %%
B = np.ones((50,3),dtype= 'uint8')
c = mm.open(b,B)
mm.show(c)

# %%
B = np.ones((5,30),dtype= 'uint8')
d = mm.close(c,B)
mm.show(d)

# %%
e = mm.infrec(d,b)
mm.show(e)

# %%
f = mm.areaopen(e,500)
mm.show(f)

# %%
mm.show(img,f)
