# %% [markdown]
# # Adesso adaptado neste Colab

# %% [markdown]
# ## Vídeos antigos
# * [Adesso4-mmd-18-27 (54min)](https://www.loom.com/share/5186fcc96309454e8e0ff90360825589), após 50m

# %%
import matplotlib.pyplot as plt
from PIL import Image
import cv2, requests, sys
import numpy as np

# %%
# download _morph.py from drive
# !pip install -U --no-cache-dir gdown --pre
# !gdown --id 1FlMtAkb0npwmD54aCysLsxB84PehcKMe
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
# ...
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1FlMtAkb0npwmD54aCysLsxB84PehcKMe
# From (redirected): https://drive.google.com/uc?id=1FlMtAkb0npwmD54aCysLsxB84PehcKMe&confirm=t&uuid=8c898627-d48b-4439-87ba-20e1ad2e6ea6
# To: /content/_morph.py
# 100% 39.2k/39.2k [00:00<00:00, 18.0MB/s]

# %%
from _morph import *

# %% [markdown]
# # mmdsoil

# %%
img = mm.read('https://drive.google.com/file/d/1arM1hCbLyPjVbkxGzFWgHAHDlpC1-BIf/view?usp=sharing')
a = cv2.cvtColor(img ,cv2.COLOR_BGR2GRAY) # converte para grayscale
mm.show(a)

# %%
b = mm.closeth(a,mm.sebox(2))
mm.show(b)

# %%
c = mm.areaopen(b,80)
mm.show(c)

# %%
d = mm.threshold(c.astype('uint8'),220)
mm.show(d)
