# %% [markdown]
# Install the `ultralytics` library.

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 873.6/873.6 kB 9.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# Create a directory named `geometricShapes` and add the `dataset` folder copied from GitHub.

# %%
# !mkdir /content/geometricShapes
# !wget https://github.com/fzampirolli/morph/raw/main/Expanded/dataset.zip -O dataset.zip
# !unzip dataset.zip -d /content/geometricShapes/
# Out:
# --2024-09-22 13:30:39--  https://github.com/fzampirolli/morph/raw/main/Expanded/dataset.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fzampirolli/morph/main/Expanded/dataset.zip [following]
# --2024-09-22 13:30:40--  https://raw.githubusercontent.com/fzampirolli/morph/main/Expanded/dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6822466 (6.5M) [application/zip]
# Saving to: ‘dataset.zip’
#
# dataset.zip         100%[===================>]   6.51M  --.-KB/s    in 0.07s
#
# 2024-09-22 13:30:40 (99.0 MB/s) - ‘dataset.zip’ saved [6822466/6822466]
#
# ...

# %% [markdown]
# The content of the `dataset` folder was generated using the following project on Roboflow:
#
# https://universe.roboflow.com/visao/geometric-shapes-5hwwu
#
# Click on the option "Download this Dataset" and choose:

# %% [markdown]
# ![Captura de Tela 2024-08-07 às 18.16.01.png](data:image/png;base64,...)

# %% [markdown]
# Utilize the `yolo` neural network provided by the `ultralytics` library for your object detection tasks.

# %%
from ultralytics import YOLO

# %% [markdown]
# Start the training with 320 epochs by running the following cell. The result of this training will be saved in:
#
# > /content/runs/detect/train/weights/best.pt
#
# This `best.pt` file will be used to make predictions on test images using the following Colab:
#
# https://colab.research.google.com/drive/1V8z_jbMoqU1OoTbn9Ikqfs_7CcFVp24o
#
# Note that the `/content/runs/detect/train/weights/` folder contains various important information about this training.
#
# To train using the Colab GPU, go to "Runtime" and "Change runtime type", and select the "T4 GPU" option. **Even so, this training can take over an hour, depending on resource availability.**

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/geometricShapes/dataset/data.yaml epochs=320 imgsz=640 plots=True
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 119MB/s]
# Ultralytics YOLOv8.2.98 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
